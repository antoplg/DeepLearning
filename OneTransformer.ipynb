# %% [markdown]
# # Deep Learning Exam  A.Y. 23/24 - 05/06/24
# ## Antonio Rapallini mat. 0001093767

# %% [markdown]
# # Sentence Reconstruction

# %% [markdown]
# The purpose of this project is to take in input a sequence of words corresponding to a random permutation of a given english sentence, and reconstruct the original sentence.
#
# The otuput can be either produced in a single shot, or through an iterative (autoregressive) loop generating a single token at a time.
#
#
# CONSTRAINTS:
# * No pretrained model can be used.
# * The neural network models should have less the 20M parameters.
# * No postprocessing should be done (e.g. no beamsearch)
# * You cannot use additional training data.
#
#
# BONUS PARAMETERS:
#
# A bonus of 0-2 points will be attributed to incentivate the adoption of models with a low number of parameters.

# %% [markdown]
# # Dataset
#
# The dataset is composed by sentences taken from the generics_kb dataset of hugging face. We restricted the vocabolary to the 10K most frequent words, and only took sentences making use of this vocabulary.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %% [markdown]
# Download the dataset

# %%
from datasets import load_dataset
from keras.layers import TextVectorization
import tensorflow as tf
import numpy as np
np.random.seed(42)
ds = load_dataset('generics_kb',trust_remote_code=True)['train']
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/8.64k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/11.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/27.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1020868 [00:00<?, ? examples/s]

# %% [markdown]
# Filter row with length greater than 8.

# %%
ds = ds.filter(lambda row: len(row["generic_sentence"].split(" ")) > 8 )
corpus = [ '<start> ' + row['generic_sentence'].replace(","," <comma>") + ' <end>' for row in ds ]
corpus = np.array(corpus)
# Out:
# Filter:   0%|          | 0/1020868 [00:00<?, ? examples/s]

# %% [markdown]
# Create a tokenizer and Detokenizer

# %%
tokenizer=TextVectorization( max_tokens=10000, standardize="lower_and_strip_punctuation", encoding="utf-8",) #con il max prende le piu frequenti. ordina i token del vocab dal piu frequente al meno frequente
tokenizer.adapt(corpus)

class TextDetokenizer:
    def __init__(self, vectorize_layer):
        self.vectorize_layer = vectorize_layer
        vocab = self.vectorize_layer.get_vocabulary()
        self.index_to_word = {index: word for index, word in enumerate(vocab)}

    def __detokenize_tokens(self, tokens):
        def check_token(t):
          if t == 3:
            s="<start>"
          elif t == 2:
            s="<end>"
          elif t == 7:
            s="<comma>"
          else:
            s=self.index_to_word.get(t, '[UNK]')
          return s

        return ' '.join([ check_token(token) for token in tokens if token != 0])

    def __call__(self, batch_tokens):
       return [self.__detokenize_tokens(tokens) for tokens in batch_tokens]


detokenizer = TextDetokenizer( tokenizer )
sentences = tokenizer( corpus ).numpy()

# %% [markdown]
# Remove from corpus the sentences where any unknow word appears

# %%
mask = np.sum( (sentences==1), axis=1) >= 1
original_data = np.delete( sentences, mask , axis=0)

# %%
original_data.shape
# Out:
# (241236, 28)

# %% [markdown]
# Shuffle the sentences

# %%
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    def __init__(self, data, batch_size=32, shuffle=True, seed=42):
        self.data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.seed = seed
        self.on_epoch_end()


    def __len__(self):
        return int(np.floor(len(self.data) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        data_batch = np.array([self.data[k] for k in indexes])
        #copy of ordered sequences
        result = np.copy(data_batch)
        #shuffle only the relevant positions for each batch
        for i in range(data_batch.shape[0]):
          np.random.shuffle(data_batch[i,1:data_batch[i].argmin() - 1])

        return data_batch , result

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.data))
        if self.shuffle:
            if self.seed is not None:
                np.random.seed(self.seed)
            np.random.shuffle(self.indexes)

# %%
# Make a random permutation of training and test set
np.random.seed(42)
# Shuffle the all data
shuffled_indices = np.random.permutation(len(original_data))
shuffled_data = original_data[shuffled_indices]

# %%
#split the dataset
train_generator = DataGenerator(shuffled_data[:220000])
test_generator = DataGenerator(shuffled_data[220000:])

# %%
x, y = test_generator.__getitem__(1)
x = detokenizer(x)
y = detokenizer(y)

for i in range(7):
  print("original: ", y[i])
  print("shuffled: ", x[i])
  print("\n")
# Out:
# original:  <start> ranchers clear large areas of rainforest to become pastures for their cattle <end>
# shuffled:  <start> large their areas for cattle ranchers rainforest clear pastures become to of <end>
#
#
# original:  <start> some earwigs have stripes on the thorax and abdomen <end>
# shuffled:  <start> stripes thorax some and the earwigs on abdomen have <end>
#
#
# original:  <start> magnetic manipulation can turn molecules in a liquid into computing such devices <end>
# shuffled:  <start> into in magnetic such a liquid molecules can manipulation computing turn devices <end>
#
#
# original:  <start> healthy wetlands means cleaner water <comma> reduced flooding and more places for recreation <end>
# shuffled:  <start> reduced wetlands and recreation for water places healthy cleaner flooding <comma> means more <end>
#
#
# original:  <start> market share is the percent share in sales one company controls in a particular market <end>
# shuffled:  <start> company percent share one controls a sales in market is share the particular in market <end>
#
#
# original:  <start> face flies spend only a small amount of time on the animal <end>
# shuffled:  <start> of on animal only a the small flies time amount spend face <end>
#
#
# original:  <start> organic foods are extremely important in prevention and management of cancer <end>
# shuffled:  <start> extremely management in of foods are prevention and cancer important organic <end>

# %% [markdown]
# # Metrics

# %% [markdown]
# Let s be the source string and p your prediction. The quality of the results will be measured according to the following metric:
#
# 1.  look for the longest substring w between s and p
# 2.  compute |w|/max(|s|,|p|)
#
# If the match is exact, the score is 1.
#
# When computing the score, you should NOT consider the start and end tokens.

# %% [markdown]
# The longest common substring can be computed with the SequenceMatcher function of difflib, that allows a simple definition of our metric.

# %%
from difflib import SequenceMatcher

def score(s,p):
  match = SequenceMatcher(None, s, p).find_longest_match()
  #print(match.size)
  return (match.size/max(len(p),len(s)))

# %% [markdown]
# Let's do an example.

# %%
original = "at first henry wanted to be friends with the king of france"
generated = "henry wanted to be friends with king of france at the first"

print("your score is ",score(original,generated))
# Out:
# your score is  0.5423728813559322

# %% [markdown]
# The score must be computed as an average of at least 3K random examples taken form the test set.

# %% [markdown]
# # What to deliver

# %% [markdown]
# You are supposed to deliver a single notebook, suitably commented.
# The notebook should describe a single model, although you may briefly discuss additional attempts you did.
#
# The notebook should contain a full trace of the training.
# Weights should be made available on request.
#
# You must also give a clear assesment of the performance of the model, computed with the metric that has been given to you.
#
# # Good work!

# %% [markdown]
# Reading some papers and doing some research on the web led me to the creation of several models.
# Several architectures widely used in text translation were then tested.
#
# - **Encoder/Decoder model based on LSTM** with attention mechanism and teacher forcing technique as presented in the paper [Effective Approaches to Attention-based Neural Machine Translation](https://arxiv.org/abs/1508.04025)
#
# - **Transformer** made based on the architecture presented within the iconic paper [Attention Is All You Need](https://arxiv.org/abs/1706.03762)
#
#
# The last one was the model used for this assignement.

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import random
import os
import pickle
import matplotlib.pyplot as plt
from tqdm import tqdm
from random import Random

from keras.models import Model
from keras.layers import MultiHeadAttention, LayerNormalization, Dense, Layer, Dropout, Embedding
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ## Creating Sets

# %%
training_set_size = 220000

# creating a full training and test set
x_train, y_train =DataGenerator(shuffled_data[:220000], batch_size=training_set_size).__getitem__(0)
x_test, y_test = DataGenerator(shuffled_data[220000:], batch_size=original_data.shape[0]-220000).__getitem__(0)

# %% [markdown]
# ## Hyperparameter

# %% [markdown]
# While building the model, at the  transformer is given his own set of hyperparameters to explore all tuning options.

# %%
VOCABULARY_SIZE = 10000

# Training Parameter
N_EPOCHS = 25
BATCH_SIZE= 128
VALIDATION_SPLIT = .2

# Beam serch parameter
BEAM_SIZE = 5


# Model Parameter
transformer_params = {
    "num_layers" : 8,                               # number of layers
    "d_model" : 128,                                # embedding dimension
    "num_heads" : 15,                                # nmber of heads
    "dff" : 254,                                    # feed forward dimension
    "input_vocab_size" : VOCABULARY_SIZE,
    "output_vocab_size" : VOCABULARY_SIZE,
    "dropout_rate" : 0.15,                          # dropout rate
    "encoder_type" : 'not-positional'
}

# %% [markdown]
# ## Model Definition

# %% [markdown]
# As mentioned earlier, the proposed model consists of a Transformers.
#
# This idea was born because researching online was found out that Transformers excel in sentence reordering due to their parallel processing, self-attention mechanism for contextual understanding, scalability, availability of pre-trained models, and flexibility to handle variable-length inputs.
#
#
# The second insight that led to the realization of this architecture is that the model does not need to give importance to the order of the shuffled sentences during encoding. It was therefore chosen to deprive the Encoders within each Transformer of Positional Embedding.

# %% [markdown]
# ### Positional Embedding

# %%
# Define the encodings

def positional_encoding(length, depth):
  depth = depth/2

  positions = np.arange(length)[:, np.newaxis]        # (seq, 1)
  depths = np.arange(depth)[np.newaxis, :]/depth      # (1, depth)

  angle_rates = 1 / (10000**depths)                   # (1, depth)
  angle_rads = positions * angle_rates                # (pos, depth)

  pos_encoding = np.concatenate([np.sin(angle_rads), np.cos(angle_rads)],
                                axis=-1)

  return tf.cast(pos_encoding, dtype=tf.float32)


class PositionalEmbedding(tf.keras.layers.Layer):
  def __init__(self, vocab_size, d_model):
    super().__init__()
    self.d_model = d_model
    self.embedding = Embedding(vocab_size,
                               d_model,
                               mask_zero=True)

    self.pos_encoding = positional_encoding(length=2048,
                                            depth=d_model)


  def compute_mask(self, *args, **kwargs):
    return self.embedding.compute_mask(*args, **kwargs)

  def call(self, x):
    length = tf.shape(x)[1]
    x = self.embedding(x)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x = x + self.pos_encoding[tf.newaxis, :length, :]
    return x


class ClassicalEmbedding(tf.keras.layers.Layer):
  def __init__(self, vocab_size, d_model):
    super().__init__()
    self.d_model = d_model
    self.embedding = Embedding(vocab_size,
                               d_model,
                               mask_zero=True)


  def call(self, x):
    x = self.embedding(x)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))

    return x

# %% [markdown]
# ### Attention Block

# %%
# Define the Attention
class Attention(Layer):
  def __init__(self, num_heads, key_dim, dropout_rate):
        super().__init__()
        self.mha = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)
        self.normalization = LayerNormalization(epsilon=1e-6)
        self.dropout = Dropout(dropout_rate)

  def call(self, query, value, key, casual_mask=False, training=True):
        attn_output = self.mha(query=query, value=value, key=key, use_causal_mask=casual_mask, training=training)
        attn_output = self.dropout(attn_output, training=training)
        #Add & Normalization
        out = self.normalization(query + attn_output)
        return out

# %% [markdown]
# ### FeedForward Block

# %%
# Define the Feed Forword
class FeedForward(Layer):
  def __init__(self, d_model, dff, dropout_rate):
        super().__init__()
        self.first_dense = Dense(dff, activation='relu')
        self.second_dense = Dense(d_model, activation='relu')
        self.norm = LayerNormalization(epsilon=1e-6)
        self.dropout = Dropout(dropout_rate)

  def call(self, x, training=True):
        fd = self.first_dense(x)
        sd = self.second_dense(fd)
        output = self.dropout(sd, training=training)
        #Add & Normalization
        output = self.norm(x + output)
        return output

# %% [markdown]
# ### Encoder Layer

# %%
# Define the Encoder layer
class EncoderLayer(Layer):

    def __init__(self, d_model, num_heads, dff, dropout_rate):
        super().__init__()
        self.self_attetion = Attention(num_heads=num_heads, key_dim=d_model, dropout_rate=dropout_rate)
        self.feed_forward = FeedForward(d_model, dff, dropout_rate)

    def call(self, x, training=True):
        attn_output = self.self_attetion(query=x, value=x, key=x, training=training)
        ffn_output = self.feed_forward(attn_output)
        return ffn_output

# %% [markdown]
# ### Encoder Block

# %%
# Define the Encoder
class Encoder(Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, dropout_rate, embedding_type):
        super().__init__()
        self.d_model = d_model
        self.num_layers = num_layers

        if embedding_type == 'positional':
          self.embedding = PositionalEmbedding(input_vocab_size, d_model)
        else:
           self.embedding =  ClassicalEmbedding(input_vocab_size, d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, dropout_rate) for _ in range(num_layers)]
        self.dropout = Dropout(dropout_rate)

    def call(self, x, training=True):
        # x is shape: (batch, seq_len)
        x = self.embedding(x)                     # (batch_size, seq_len, d_model)
        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training=training)

        return x      # (batch_size, seq_len, d_model)

# %% [markdown]
# ### Decoder Layer

# %%
# Define the Decoder layer
class DecoderLayer(Layer):

    def __init__(self, d_model, num_heads, dff, dropout_rate):
        super(DecoderLayer, self).__init__()
        self.self_attention = Attention(num_heads=num_heads, key_dim=d_model, dropout_rate=dropout_rate)
        self.mha = Attention(num_heads=num_heads, key_dim=d_model, dropout_rate=dropout_rate)
        self.feed_forward = FeedForward(d_model, dff, dropout_rate)


    def call(self, x, enc_output, training=True):
        self_attention = self.self_attention(query=x, value=x, key=x, casual_mask=True, training=training)
        multi_head_attention = self.mha(query=self_attention, value=enc_output, key=enc_output, training=training)
        ffn_output = self.feed_forward(multi_head_attention)    # (batch_size, seq_len, d_model)

        return ffn_output

# %% [markdown]
# ### Decoder Block

# %%
# Define the Decoder
class Decoder(Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, dropout_rate):
        super(Decoder, self).__init__()
        self.d_model = d_model
        self.num_layers = num_layers

        self.pos_encoding = PositionalEmbedding(target_vocab_size, d_model)
        self.dropout = Dropout(dropout_rate)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, dropout_rate) for _ in range(num_layers)]

    def call(self, x, enc_output, training=True):
        # x is shape (batch, target_seq_len)
        x = self.pos_encoding(x)                  # (batch_size, target_seq_len, d_model)
        x = self.dropout(x, training=training)
        for i in range(self.num_layers):
            x = self.dec_layers[i](x, enc_output, training=training)

        return x      # (batch_size, target_seq_len, d_model)

# %% [markdown]
# ### Metrics

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super().__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps


  def __call__(self, step):
    step = tf.cast(step, dtype=tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

def masked_loss(label, pred):
  mask = label != 0
  loss_object = SparseCategoricalCrossentropy(
    from_logits=False, reduction='none')
  loss = loss_object(label, pred)

  mask = tf.cast(mask, dtype=loss.dtype)
  loss *= mask

  loss = tf.reduce_sum(loss)/tf.reduce_sum(mask)
  return loss


def masked_accuracy(label, pred):
  pred = tf.argmax(pred, axis=2)
  label = tf.cast(label, pred.dtype)
  match = label == pred

  mask = label != 0

  match = match & mask

  match = tf.cast(match, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(match)/tf.reduce_sum(mask)

# %% [markdown]
# ### Transformer

# %%
class Transformer(Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, output_vocab_size, dropout_rate, encoder_type, output_shape):
        super(Transformer, self).__init__()
        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, dropout_rate, encoder_type)
        self.decoder = Decoder(num_layers, d_model, num_heads, dff, output_vocab_size, dropout_rate)
        self.final_layer = Dense(output_vocab_size, activation='softmax')

    def call(self, input, training=True):
        context, input_sentence = input
        encoder_output = self.encoder(context, training=training)                              # (batch_size, context_len, d_model)
        decoder_output = self.decoder(input_sentence, encoder_output, training=training)       # (batch_size, target_len, d_model)
        final_output = self.final_layer(decoder_output)                                        # (batch_size, target_len, vocab_size)
        try:
          del final_output._keras_mask
        except AttributeError:
          pass

        return final_output


    def save(self, path ):
      self.transformer.save_weights(path)

    def load(self, path):
      self.transformer_1.load_weights(path)


  # A customized training method that makes the two transformers train separately
    def fit(self, x, y, validation_split = .1, epochs=6, batch_size=256, callbacks=[]):
      x1, x2 = x
      data_size = x1.shape[0]

      print('-'*200)
      print("training transformer:")
      print('-' * 200)
      history = super(Transformer, self).fit([x1[:data_size],
                                        x2[:data_size]],
                                        y[:data_size],
                                        epochs=epochs,
                                        batch_size=batch_size,
                                        validation_split=validation_split,
                                        callbacks=callbacks
                                        )

      return history

# %% [markdown]
# ## Model Creation

# %%
model = Transformer(**transformer_params,  output_shape=VOCABULARY_SIZE)
model([y_train[:1], x_train[:1]])
model.summary()
# Out:
# Model: "transformer_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_7 (Encoder)         multiple                  3389944
#
#  decoder_7 (Decoder)         multiple                  5237240
#
#  dense_135 (Dense)           multiple                  1290000
#
# =================================================================
# Total params: 9917184 (37.83 MB)
# Trainable params: 9917184 (37.83 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
learning_rate = CustomSchedule(128)
optimizer = Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

model.compile(loss=masked_loss,
              optimizer=optimizer,
              metrics=[masked_accuracy])

# %% [markdown]
# ## Fitting the model

# %%
train = True

path_folder = '/content/drive/My Drive/weights'

path_weigth1 = os.path.join(path_folder, 'best_weights_5.weights.h5')

if train:
  # Definition of the callbacks that save the best weigths

  checkpoint_callback = ModelCheckpoint(filepath=path_weigth1,
                                          monitor='val_loss',
                                          save_best_only=True,
                                          save_weights_only=True,
                                          mode='min',
                                          verbose=1
                                        )


  # Definition of the callbacks that stop the trainin process if  for 5 epochs the  val_loss dont decreas at last of 0.0009

  early_stopping = EarlyStopping(monitor='val_loss',             # Metric to monitor
                                patience=5,                      # Number of consecutive epochs without improvement
                                restore_best_weights=True,       # Restore weights of the best epoch
                                mode='min',                      # minimizing
                                min_delta=0.001,                 # minimum change between two epochs
                                verbose=1
                                )



  history = model.fit([x_train, y_train[:,:-1]],
                                    y_train[:,1:],
                                    epochs=N_EPOCHS,
                                    batch_size=BATCH_SIZE,
                                    validation_split = VALIDATION_SPLIT,
                                    callbacks=[early_stopping, checkpoint_callback],
                                   )
else:
  model.load('/content/drive/My Drive/weights/best_weights_5.weights.h5')
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# training transformer 1:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/25
# 1375/1375 [==============================] - ETA: 0s - loss: 5.9404 - masked_accuracy: 0.2745
# Epoch 1: val_loss improved from inf to 3.62453, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 151s 90ms/step - loss: 5.9404 - masked_accuracy: 0.2745 - val_loss: 3.6245 - val_masked_accuracy: 0.4897
# Epoch 2/25
# 1375/1375 [==============================] - ETA: 0s - loss: 2.6289 - masked_accuracy: 0.5795
# Epoch 2: val_loss improved from 3.62453 to 1.74137, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 111s 81ms/step - loss: 2.6289 - masked_accuracy: 0.5795 - val_loss: 1.7414 - val_masked_accuracy: 0.6698
# Epoch 3/25
# 1375/1375 [==============================] - ETA: 0s - loss: 1.5811 - masked_accuracy: 0.6759
# Epoch 3: val_loss improved from 1.74137 to 1.27380, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 112s 82ms/step - loss: 1.5811 - masked_accuracy: 0.6759 - val_loss: 1.2738 - val_masked_accuracy: 0.7221
# Epoch 4/25
# 1375/1375 [==============================] - ETA: 0s - loss: 1.2104 - masked_accuracy: 0.7226
# Epoch 4: val_loss improved from 1.27380 to 1.01825, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 111s 81ms/step - loss: 1.2104 - masked_accuracy: 0.7226 - val_loss: 1.0183 - val_masked_accuracy: 0.7601
# Epoch 5/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.9838 - masked_accuracy: 0.7587
# Epoch 5: val_loss improved from 1.01825 to 0.92435, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 111s 81ms/step - loss: 0.9838 - masked_accuracy: 0.7587 - val_loss: 0.9243 - val_masked_accuracy: 0.7780
# Epoch 6/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.8494 - masked_accuracy: 0.7830
# Epoch 6: val_loss improved from 0.92435 to 0.86151, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.8494 - masked_accuracy: 0.7830 - val_loss: 0.8615 - val_masked_accuracy: 0.7953
# Epoch 7/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.7592 - masked_accuracy: 0.8002
# Epoch 7: val_loss improved from 0.86151 to 0.82212, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.7592 - masked_accuracy: 0.8002 - val_loss: 0.8221 - val_masked_accuracy: 0.8009
# Epoch 8/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.6892 - masked_accuracy: 0.8147
# Epoch 8: val_loss improved from 0.82212 to 0.80509, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.6892 - masked_accuracy: 0.8147 - val_loss: 0.8051 - val_masked_accuracy: 0.8075
# Epoch 9/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.6340 - masked_accuracy: 0.8266
# Epoch 9: val_loss improved from 0.80509 to 0.78161, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.6340 - masked_accuracy: 0.8266 - val_loss: 0.7816 - val_masked_accuracy: 0.8121
# Epoch 10/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.5920 - masked_accuracy: 0.8356
# Epoch 10: val_loss improved from 0.78161 to 0.76576, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.5920 - masked_accuracy: 0.8356 - val_loss: 0.7658 - val_masked_accuracy: 0.8180
# Epoch 11/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.5540 - masked_accuracy: 0.8439
# Epoch 11: val_loss improved from 0.76576 to 0.75377, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.5540 - masked_accuracy: 0.8439 - val_loss: 0.7538 - val_masked_accuracy: 0.8212
# Epoch 12/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.5233 - masked_accuracy: 0.8512
# Epoch 12: val_loss improved from 0.75377 to 0.75168, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.5233 - masked_accuracy: 0.8512 - val_loss: 0.7517 - val_masked_accuracy: 0.8218
# Epoch 13/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.4958 - masked_accuracy: 0.8577
# Epoch 13: val_loss improved from 0.75168 to 0.74987, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 109s 80ms/step - loss: 0.4958 - masked_accuracy: 0.8577 - val_loss: 0.7499 - val_masked_accuracy: 0.8250
# Epoch 14/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.4724 - masked_accuracy: 0.8633
# Epoch 14: val_loss did not improve from 0.74987
# 1375/1375 [==============================] - 107s 78ms/step - loss: 0.4724 - masked_accuracy: 0.8633 - val_loss: 0.7508 - val_masked_accuracy: 0.8249
# Epoch 15/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.4505 - masked_accuracy: 0.8688
# Epoch 15: val_loss improved from 0.74987 to 0.74344, saving model to /content/drive/My Drive/weights/best_weights_5.weights.h5
# 1375/1375 [==============================] - 110s 80ms/step - loss: 0.4505 - masked_accuracy: 0.8688 - val_loss: 0.7434 - val_masked_accuracy: 0.8271
# Epoch 16/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.4324 - masked_accuracy: 0.8730
# Epoch 16: val_loss did not improve from 0.74344
# 1375/1375 [==============================] - 108s 78ms/step - loss: 0.4324 - masked_accuracy: 0.8730 - val_loss: 0.7626 - val_masked_accuracy: 0.8273
# Epoch 17/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.4155 - masked_accuracy: 0.8777
# Epoch 17: val_loss did not improve from 0.74344
# 1375/1375 [==============================] - 107s 78ms/step - loss: 0.4155 - masked_accuracy: 0.8777 - val_loss: 0.7556 - val_masked_accuracy: 0.8301
# Epoch 18/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.3998 - masked_accuracy: 0.8814
# Epoch 18: val_loss did not improve from 0.74344
# 1375/1375 [==============================] - 107s 78ms/step - loss: 0.3998 - masked_accuracy: 0.8814 - val_loss: 0.7555 - val_masked_accuracy: 0.8317
# Epoch 19/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.3866 - masked_accuracy: 0.8848
# Epoch 19: val_loss did not improve from 0.74344
# 1375/1375 [==============================] - 107s 78ms/step - loss: 0.3866 - masked_accuracy: 0.8848 - val_loss: 0.7585 - val_masked_accuracy: 0.8318
# Epoch 20/25
# 1375/1375 [==============================] - ETA: 0s - loss: 0.3740 - masked_accuracy: 0.8880Restoring model weights from the end of the best epoch: 15.
#
# Epoch 20: val_loss did not improve from 0.74344
# 1375/1375 [==============================] - 107s 78ms/step - loss: 0.3740 - masked_accuracy: 0.8880 - val_loss: 0.7656 - val_masked_accuracy: 0.8327
# Epoch 20: early stopping

# %% [markdown]
# ## Plotting the training process

# %%
def display_history(model_fit, model_name):
    print(model_fit)
    mse_training = model_fit.history['loss']
    acc_training = model_fit.history['masked_accuracy']

    mse_val = model_fit.history['val_loss']
    acc_val = model_fit.history['val_masked_accuracy']

    fig, axs = plt.subplots(1, 2, figsize=(15, 4))

    axs[0].plot(mse_training)
    axs[0].plot(mse_val)
    axs[0].grid()
    axs[0].set_title('Loss during training')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Training', 'Validation'])

    axs[1].plot(acc_training)
    axs[1].plot(acc_val)
    axs[1].grid()
    axs[1].set_title('Accuracy during training')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Training', 'Validation'])

    fig.text(0.5, 0.95, 'Training History ' + model_name, ha='center', va='top', fontsize=16)
    fig.subplots_adjust(top=0.75)

    plt.show()

display_history(history, 'Transformer')
# Out:
# <keras.src.callbacks.History object at 0x7c106c1a6cb0>

# %% [markdown]
# The charts indicate that the validation test's loss and accuracy closely track the training values, with only a minor discrepancy. There are no significant signs of Overfitting observed.

# %% [markdown]
# ## Test the Model

# %% [markdown]
# The realized model generates sentences one token at a time by basing the generation of a new token on the previous one.
# The choice of this token can be made through several strategies, the one used here is:
#
# - **GreedySearch**: simple implementation and high performance from the point of view of computational complexity
#
# This technique generates each token by extracting the one with the highest probability of being associated with the previous token, from the list of probabilities assigned to each token given in output by the model.

# %% [markdown]
# ### Gready Search  Definition

# %%
def greedySearch(input_sequence, masking=True):
    output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
    output_array = output_array.write(0, 3)
    stop_condition = False

    for i in range(28):
      output = tf.transpose(output_array.stack())
      output = output.numpy().reshape((1,output.shape[0]))
      predictions = model([input_sequence, output], training=False)
      predictions = predictions[0, -1:, :]
      predictions = predictions.numpy()
      predicted_id = tf.argmax(predictions, axis=-1)
      output_array = output_array.write(i+1, predicted_id[0])

      if predicted_id == 2:
        break

    output = tf.transpose(output_array.stack())
    return output.numpy()


def convert_sequence(input_sequence):
    mask = [0, 1, 2, 3]
    input_sequence = np.array(input_sequence)
    input_sequence = input_sequence[~np.isin(input_sequence, mask)]
    input_sequence = detokenizer([input_sequence])
    return input_sequence

# %% [markdown]
# ### Comparison between Target Sentences and GreedySearch

# %% [markdown]
# An initial test case was chosen by going to consider a small set of number of items so that the quality of sentence reconstruction through the Greedy Search technique could be verified visually.
#
# > Aggiungi citazione

# %%
nbr_sents_2_test = 50

scores_vector_beam_seach = []
scores_vector_arg_max = []

for i in range(nbr_sents_2_test):
  print('-'*200)
  print(i, "/", nbr_sents_2_test)

  print('Index phrase:', i)
  s = convert_sequence(y_test[i])[0].replace(' <comma>', ',')
  print("Correct sequence     :", s)
  p = convert_sequence(greedySearch(x_test[i].reshape(1,28), VOCABULARY_SIZE))[0].replace(' <comma>', ',')
  print("Predict sequence arg :", p)
  sco_argmax = score(p,s)

  print("Score with arg max:    ", sco_argmax)

  scores_vector_arg_max.append(sco_argmax)

my_score_argmax = np.mean(scores_vector_arg_max)

print('=' * 200)
print("Final Score armax:", my_score_argmax)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 / 50
# Index phrase: 0
# Correct sequence     : recycling prevents pollution and helps conserve precious natural resources
# Predict sequence arg : recycling helps conserve natural resources and prevents precious pollution
# Score with arg max:     0.24324324324324326
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1 / 50
# Index phrase: 1
# Correct sequence     : predators like to eat banana slugs at all stages of their lives
# Predict sequence arg : banana slugs like to eat predators at all stages of their lives
# Score with arg max:     0.47619047619047616
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2 / 50
# Index phrase: 2
# Correct sequence     : corporate profits drive stock prices and corporations have been getting serious about business
# Predict sequence arg : corporations drive profits about business prices and have been getting serious corporate stock
# Score with arg max:     0.2872340425531915
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 3 / 50
# Index phrase: 3
# Correct sequence     : snails are hermaphrodites but they have to mate before laying some days later
# Predict sequence arg : some snails are hermaphrodites but they have to mate later before laying days
# Score with arg max:     0.6233766233766234
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 4 / 50
# Index phrase: 4
# Correct sequence     : abuse can affect any family regardless of income, profession, religion, or education
# Predict sequence arg : abuse can affect any profession, regardless of income, religion, or family education
# Score with arg max:     0.27380952380952384
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 5 / 50
# Index phrase: 5
# Correct sequence     : agriculture provides open space, wildlife habitat and economic activity
# Predict sequence arg : agriculture provides open space, wildlife habitat and economic activity
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 6 / 50
# Index phrase: 6
# Correct sequence     : soups make it possible to eat indian food on the go
# Predict sequence arg : soups go on the indian food to make it eat possible
# Score with arg max:     0.2549019607843137
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 7 / 50
# Index phrase: 7
# Correct sequence     : healthy living is distorted when a single problem is the focus, and others ignored
# Predict sequence arg : problem is a single focus when the role is ignored, others healthy and living
# Score with arg max:     0.13414634146341464
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 8 / 50
# Index phrase: 8
# Correct sequence     : milkweed is a perennial that often bears blossoms and fruit at the same time
# Predict sequence arg : perennial milkweed is often a fruit that bears blossoms and fruit at the same time
# Score with arg max:     0.5121951219512195
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 9 / 50
# Index phrase: 9
# Correct sequence     : severe malnutrition is a serious, lifethreatening condition for children
# Predict sequence arg : malnutrition is a serious, lifethreatening condition for severe children
# Score with arg max:     0.7916666666666666
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 10 / 50
# Index phrase: 10
# Correct sequence     : humans have the power to make wrong choices and to make mistakes
# Predict sequence arg : humans have the power to make mistakes and to make wrong choices
# Score with arg max:     0.46875
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 11 / 50
# Index phrase: 11
# Correct sequence     : dandelions are believed to be some of the oldest plants on the planet
# Predict sequence arg : dandelions are believed to be some of the oldest plants on the planet
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 12 / 50
# Index phrase: 12
# Correct sequence     : caffeine is a drug found in a number of plants like coffee beans, cocoa beans, and tea leaves
# Predict sequence arg : caffeine is a drug found in cocoa beans like coffee beans, tea leaves, and a number of plants
# Score with arg max:     0.3010752688172043
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 13 / 50
# Index phrase: 13
# Correct sequence     : most people connect to the internet using modems and telephone lines
# Predict sequence arg : most people connect using telephone lines and modems to the internet
# Score with arg max:     0.29411764705882354
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 14 / 50
# Index phrase: 14
# Correct sequence     : viral transmission is most successful when density of hosts is high
# Predict sequence arg : viral density is most successful when transmission of hosts is high
# Score with arg max:     0.373134328358209
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 15 / 50
# Index phrase: 15
# Correct sequence     : instant cameras use film that provides a print without first being developed into a negative
# Predict sequence arg : instant cameras use a film that provides developed first a print without being into negative
# Score with arg max:     0.21739130434782608
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 16 / 50
# Index phrase: 16
# Correct sequence     : rice milk contains only water, rice, oil and salt
# Predict sequence arg : rice contains only salt water, oil, rice and milk
# Score with arg max:     0.30612244897959184
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 17 / 50
# Index phrase: 17
# Correct sequence     : muskrats eat a variety of food, though, and usually are able to maintain high population levels
# Predict sequence arg : muskrats are usually able to eat a variety of food, though, and maintain high population levels
# Score with arg max:     0.37894736842105264
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 18 / 50
# Index phrase: 18
# Correct sequence     : surgery is often the first and best treatment for cancer
# Predict sequence arg : surgery is often the best treatment for cancer and first
# Score with arg max:     0.4642857142857143
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 19 / 50
# Index phrase: 19
# Correct sequence     : sign language make a difference by helping the deaf talk
# Predict sequence arg : sign language make a difference by helping talk the deaf
# Score with arg max:     0.7857142857142857
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 20 / 50
# Index phrase: 20
# Correct sequence     : intense concentration is used to focus as much strength as possible on the object of impact
# Predict sequence arg : strength is used to impact on the concentration of intense object as much as possible focus
# Score with arg max:     0.17582417582417584
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 21 / 50
# Index phrase: 21
# Correct sequence     : some plants make use of multiple vectors, but many are highly specialised
# Predict sequence arg : many plants are highly specialised, but some make use of multiple vectors
# Score with arg max:     0.3972602739726027
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 22 / 50
# Index phrase: 22
# Correct sequence     : natural enemies play an important role during periods when gypsy moth populations are sparse
# Predict sequence arg : natural enemies play an important role during gypsy moth periods when populations are sparse
# Score with arg max:     0.5
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 23 / 50
# Index phrase: 23
# Correct sequence     : organisms can survive only in environments in which their needs are met
# Predict sequence arg : organisms can survive only in environments in which their needs are met
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 24 / 50
# Index phrase: 24
# Correct sequence     : small animals experience too much friction relative to their muscle strength to go fast
# Predict sequence arg : small animals experience too much strength to go fast relative to their muscle friction
# Score with arg max:     0.39080459770114945
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 25 / 50
# Index phrase: 25
# Correct sequence     : jams tend to hold their shape but are generally less firm than jelly
# Predict sequence arg : jams generally tend to hold their shape but are less firm than jelly
# Score with arg max:     0.5
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 26 / 50
# Index phrase: 26
# Correct sequence     : special herbs can enhance the diet and promote the bodys ability to sustain cellular balance
# Predict sequence arg : special herbs can promote the bodys ability to sustain the bodys diet and enhance cellular balance
# Score with arg max:     0.3877551020408163
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 27 / 50
# Index phrase: 27
# Correct sequence     : macaws can still have a limited amount of flight due to their large wing web area
# Predict sequence arg : macaws can still have a limited amount of wing due to their large flight web area
# Score with arg max:     0.5185185185185185
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 28 / 50
# Index phrase: 28
# Correct sequence     : some species adapt much more rapidly to new conditions than others
# Predict sequence arg : some new species adapt much more rapidly than others to conditions
# Score with arg max:     0.5151515151515151
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 29 / 50
# Index phrase: 29
# Correct sequence     : trees are generally lower than the rainforest trees, but again have massive trunks
# Predict sequence arg : rainforest trees have massive trunks than trees, but are generally lower again the
# Score with arg max:     0.25609756097560976
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 30 / 50
# Index phrase: 30
# Correct sequence     : young trees can make six feet of growth in a single season
# Predict sequence arg : young trees can make six feet in a single season of growth
# Score with arg max:     0.5172413793103449
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 31 / 50
# Index phrase: 31
# Correct sequence     : smokers tend to reach menopause at an earlier age than nonsmokers
# Predict sequence arg : smokers tend to reach menopause at an earlier age than nonsmokers
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 32 / 50
# Index phrase: 32
# Correct sequence     : ranchers clear large areas of rainforest to become pastures for their cattle
# Predict sequence arg : ranchers become large areas of clear rainforest for cattle to their pastures
# Score with arg max:     0.21052631578947367
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 33 / 50
# Index phrase: 33
# Correct sequence     : some earwigs have stripes on the thorax and abdomen
# Predict sequence arg : some earwigs have stripes on the thorax and abdomen
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 34 / 50
# Index phrase: 34
# Correct sequence     : magnetic manipulation can turn molecules in a liquid into computing such devices
# Predict sequence arg : magnetic devices can turn magnetic manipulation into such molecules in a computing
# Score with arg max:     0.2682926829268293
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 35 / 50
# Index phrase: 35
# Correct sequence     : healthy wetlands means cleaner water, reduced flooding and more places for recreation
# Predict sequence arg : healthy wetlands means more water cleaner places for flooding, flooding and recreation
# Score with arg max:     0.26744186046511625
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 36 / 50
# Index phrase: 36
# Correct sequence     : market share is the percent share in sales one company controls in a particular market
# Predict sequence arg : sales is one percent market controls in the share in a particular company market share
# Score with arg max:     0.19767441860465115
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 37 / 50
# Index phrase: 37
# Correct sequence     : face flies spend only a small amount of time on the animal
# Predict sequence arg : face flies spend only a small amount of time on the animal
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 38 / 50
# Index phrase: 38
# Correct sequence     : organic foods are extremely important in prevention and management of cancer
# Predict sequence arg : organic foods are extremely important in prevention and management of cancer
# Score with arg max:     1.0
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 39 / 50
# Index phrase: 39
# Correct sequence     : fungicides can be effective management tools for lettuce diseases caused by fungi
# Predict sequence arg : fungicides can be effective tools for diseases management caused by lettuce fungi
# Score with arg max:     0.345679012345679
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 40 / 50
# Index phrase: 40
# Correct sequence     : most blister agents cause little or no pain at the time of exposure
# Predict sequence arg : blister agents cause little or no pain at most of the time exposure
# Score with arg max:     0.6268656716417911
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 41 / 50
# Index phrase: 41
# Correct sequence     : lines of force exist between two poles which are labeled as positive and negative
# Predict sequence arg : negative lines exist as positive and negative lines of force between which two are labeled
# Score with arg max:     0.2777777777777778
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 42 / 50
# Index phrase: 42
# Correct sequence     : cerebral palsy is due to abnormal development or damage occurring to the developing brain
# Predict sequence arg : cerebral palsy is due to damage occurring abnormal to the developing brain or development
# Score with arg max:     0.2808988764044944
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 43 / 50
# Index phrase: 43
# Correct sequence     : birds are meant to fly and be with others of their own kind in a natural environment
# Predict sequence arg : birds are meant to fly in their own environment with others and be a kind of natural
# Score with arg max:     0.27380952380952384
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 44 / 50
# Index phrase: 44
# Correct sequence     : some herbicides are available in combination with a fertilizer
# Predict sequence arg : some herbicides are available in a combination with fertilizer
# Score with arg max:     0.532258064516129
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 45 / 50
# Index phrase: 45
# Correct sequence     : plants provide fuel, food, clothing, and even shelter, either directly or indirectly
# Predict sequence arg : plants provide food, shelter, food, and clothing, either directly or even indirectly
# Score with arg max:     0.25
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 46 / 50
# Index phrase: 46
# Correct sequence     : bats demand roosting chambers, darkness during the day and warmth
# Predict sequence arg : bats demand chambers during the day, warmth and darkness chambers
# Score with arg max:     0.24615384615384617
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 47 / 50
# Index phrase: 47
# Correct sequence     : macaques are hardy, intelligent primates with stout bodies and powerful limbs
# Predict sequence arg : macaques are hardy primates, with stout bodies and powerful limbs
# Score with arg max:     0.4805194805194805
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 48 / 50
# Index phrase: 48
# Correct sequence     : infertility can be a major crisis because the important life goal of parenthood is threatened
# Predict sequence arg : infertility is important because the goal of life can be threatened life a major crisis
# Score with arg max:     0.17204301075268819
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 49 / 50
# Index phrase: 49
# Correct sequence     : carrion flies can arrive at, and lay eggs on, a dead animal within minutes
# Predict sequence arg : flies can arrive at minutes, and lay dead animal eggs within a carrion at minutes
# Score with arg max:     0.2345679012345679
# ========================================================================================================================================================================================================
# Final Score armax: 0.46018927864916315

# %% [markdown]
# ### Final Test

# %% [markdown]
# A more general test case was chosen considering a set of 3000 sentences to be reordered to produce the required score.
# The test was carried out to highlight the performance achieved by the model using Greedy Search with a big load of data.

# %% [markdown]
# #### Final results

# %% [markdown]
# The following is the result obtained by applying the GreedySearch

# %%
# This function has been implemented in order to speed up the test
def predictBatch(input_sequences):
        batch_size = input_sequences.shape[0]
        encoder_input = input_sequences
        decoded_indexes = [[3] for _ in range(batch_size)]

        for i in range(1, 28):
            decoder_input = tf.convert_to_tensor(decoded_indexes)

            predictions = np.array(model([encoder_input, decoder_input], training=False))
            predictions = predictions[:, -1, :]
            sampled_token_index = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

            for ind in range(batch_size):
              decoded_indexes[ind].append(int(sampled_token_index[ind]))


        return decoded_indexes

# %%
total_score = 0
num_examples = 3000
start_id = 0
batch = 500
# Instantiate the Random instance with random seed = 42 to ensure reproducibility
randomizer = Random(42)

possible_choice = [i for i in range(len(x_test))]
random.shuffle(possible_choice)
predicted_sequences_tot = []

for i in tqdm(range(start_id, (start_id+num_examples)//batch)):
  begin = i*batch
  end = (i+1)*batch

  predicted_sequences = predictBatch(x_test[possible_choice[begin:end]])
  predicted_sequences_tot += predicted_sequences


for i in (range(start_id, start_id+num_examples)):
    original_sentence = detokenizer([y_test[possible_choice[i]]])[0].replace(' <comma>', ',').replace('<start> ', '').replace(' <end>', '')

    prediction = predicted_sequences_tot[i]
    if(2 in prediction):
      end_token_index = prediction.index(2)
      prediction = prediction[:end_token_index+1]

    predicted_sentence = detokenizer([prediction])
    predicted_sentence = predicted_sentence[0].replace(' <comma>', ',').replace('<start> ', '').replace(' <end>', '')

    total_score += score(predicted_sentence, original_sentence)

arg_max_score = (total_score / num_examples)


print('\n======================================================================')
print("|               FINAL SCORE:                     ", arg_max_score   ,"|")
print('======================================================================')
# Out:
# 100%|██████████| 6/6 [01:11<00:00, 11.85s/it]
# ======================================================================
# |               FINAL SCORE:                      0.5021763371594588 |
# ======================================================================

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In the first evaluation, which included 50 sentences, a minor value in the score was noted (0.46018927864916315), for the concluding evaluation, carried out with 3000 sentences as specified, GreedySearch showed a marginally superior performance.
#
#
# **MY BEST SCORE**
# ---
#
# **0.5021763371594588**.
#
# ---
